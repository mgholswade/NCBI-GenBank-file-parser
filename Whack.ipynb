# %%
import pandas as pd
import io
import re

# %% [markdown]
# # GenDB_2.0
#
# Changes from 1.0:
# 1. Modify to use TPM from 6 quant files in place of full table of single quant file

# %% [markdown]
# mte-1-1_updated_quants.sf,mte-1-2_update_quants.sf,mte-1-3_update_quants.sf,mte-2-1_updated_quants.sf,mte-2-2_update_quants.sf,mte-2-3_update_quants.sf

# %%
fileNames = input('Enter relative paths for quantity files to be used, seperated by commas (include .sf): ')
fileList = fileNames.split(',')

tpmdf = pd.DataFrame()

#FIXME 2/7 This block is some shit ass code but its working, fix in future release
quants_file = open('C:/Users/mghol/Documents/Projects/GenDB/' + fileList[0])
quants_string = quants_file.read()

quants_string = quants_string.replace('\\',',')
quants_string = quants_string.replace('\t',',')
quants_string = re.sub(r'(MTE_[0-9]*)([\w\-\.]*),',r'\1,',quants_string)

quants = pd.read_csv(io.StringIO(quants_string))
Name = pd.DataFrame({'Name':quants['Name']})#,columns=['TPM_'+file]) #FIXME 2/6 Adding column names is resulting in empty df

tpmdf = pd.concat([tpmdf,Name],axis=1)



for file in fileList:
    quants_file = open('C:/Users/mghol/Documents/Projects/GenDB/' + file)
    quants_string = quants_file.read()

    quants_string = quants_string.replace('\\',',')
    quants_string = quants_string.replace('\t',',')
    # 2/28 Commented out to try to fix final join
    quants_string = re.sub(r'(FUN_[0-9]*)([\w\-\.]*),',r'\1,',quants_string)

    quants = pd.read_csv(io.StringIO(quants_string))
    
    TPM = pd.DataFrame({file:quants['TPM']})#,columns=['TPM_'+file]) #FIXME 2/6 Adding column names is resulting in empty df
    
    tpmdf = pd.concat([tpmdf,TPM],axis=1)

# %%
tpmdf
# Out:
#              Name  mte-1-1_updated_quants.sf  mte-1-2_update_quants.sf  \
# 0      MTE_000001                  62.477691                 61.940994
# 1      MTE_000002                  33.154793                102.547914
# 2      MTE_000003                  63.217507                 59.107631
# 3      MTE_000004                  24.402535                 29.204258
# 4      MTE_000005                 199.402737                239.741840
# ...           ...                        ...                       ...
# 12170  MTE_010710                   2.149945                  0.582032
# 12171  MTE_010711                   0.655969                  0.000000
# 12172  MTE_010712                  56.412165                 16.167001
# 12173  MTE_010713                   0.000000                  0.000000
# 12174  MTE_010714                   0.000000                  0.000000
#
#        mte-1-3_update_quants.sf  mte-2-1_updated_quants.sf  \
# 0                     64.240050                 131.354755
# 1                    123.010667                  31.078452
# 2                     61.221236                 125.471561
# 3                     31.326675                  65.327440
# 4                    233.668345                 261.667857
# ...                         ...                        ...
# 12170                  0.557513                   0.000000
# 12171                  0.310917                   1.941869
# 12172                 18.946223                 325.330134
# 12173                  0.000000                   0.000000
# 12174                  0.000000                   0.000000
#
#        mte-2-2_update_quants.sf  mte-2-3_update_quants.sf
# 0                    126.017399                162.615634
# 1                     27.686279                 22.262655
# 2                    133.331054                113.497131
# 3                     60.106444                 46.687113
# 4                    282.108737                219.341086
# ...                         ...                       ...
# 12170                  0.000000                  0.000000
# 12171                  1.821012                  2.769717
# 12172                351.141528                260.510759
# 12173                  0.000000                  0.000000
# 12174                  0.000000                  0.000000
#
# [12175 rows x 7 columns]

# %%
#ORIGINAL CODE
# gff3_file = open('E:/Work/Database/annotate_results/Mattiorlomyces_terfezioides.gff3')
# gff3_string = gff3_file.read()

# gff3_string = gff3_string.replace('\\',' ')
# gff3_string = gff3_string.replace('\t',' ')
# gff3_stsring = gff3_string.replace(';',' ')
# gff3_string = re.sub('ID=[\w\-\.]*;','',gff3_string)
# gff3_string = re.sub(r'Parent=(FUN_[0-9]*)([\w\-\.]*);',r'\1 ',gff3_string)


# #FIXME: This drops product information. Should be modified to preserve product, but change whitespace to _
# gff3_string = re.sub(r'product=[\w \-\.\'\\\(\,\/\+\:)]*?;',r'',gff3_string)
# gff3_string = re.sub(r'product=[^;]*?;',r'',gff3_string)


# newfile = open('test.txt','w')
# newfile.write(gff3_string)
# Out:
# 6351671

# %%
#NEW CODE
gff3_file = open('C:/Users/mghol/Documents/Projects/GenDB/Mattirolomyces_terfezioides.gff3')
gff3_string = gff3_file.read()

gff3_string = gff3_string.replace('\\',' ')
gff3_string = gff3_string.replace('\t',' ')
gff3_stsring = gff3_string.replace(';',' ')
gff3_string = re.sub('ID=[\w\-\.]*;','',gff3_string)
# 2/28 Commented out to try to fix final join
gff3_string = re.sub(r'Parent=(MTE_[0-9]*)([\w\-\.]*);',r'\1 ',gff3_string)


#This is super fucked up but I havent figured out how to loop this until there are no more spaces in product tags, this will work as long as names
#arent longer than 7 words.
gff3_string = re.sub(r'product=([\S_]*) ',r'product=\1_',gff3_string)
gff3_string = re.sub(r'product=([\S_]*) ',r'product=\1_',gff3_string)
gff3_string = re.sub(r'product=([\S_]*) ',r'product=\1_',gff3_string)
gff3_string = re.sub(r'product=([\S_]*) ',r'product=\1_',gff3_string)
gff3_string = re.sub(r'product=([\S_]*) ',r'product=\1_',gff3_string)
gff3_string = re.sub(r'product=([\S_]*) ',r'product=\1_',gff3_string)


newfile = open('test.txt','w')
newfile.write(gff3_string)
# Out:
# 7910788

# %%
f = open("test.txt", "r")
data = [line.split() for line in f]

data = data[1:]
masterList = []
for line in data:
    newlist = []
    for item in line:
        newlist.append(item)
    masterList.append(newlist)

df = pd.DataFrame.from_dict(masterList)
df.columns = ['Scaffold','Source','Type','Start','End','A','B','C','Name','Details']

# %%
df
# Out:
#             Scaffold       Source            Type Start   End  A  B  C  \
# 0         scaffold_1  funannotate            gene    38  6230  .  -  .
# 1         scaffold_1  funannotate            mRNA    38  6230  .  -  .
# 2         scaffold_1  funannotate  five_prime_UTR  5729  6230  .  -  .
# 3         scaffold_1  funannotate            exon  5630  6230  .  -  .
# 4         scaffold_1  funannotate            exon  5404  5562  .  -  .
# ...              ...          ...             ...   ...   ... .. .. ..
# 125371  scaffold_679  funannotate            exon   338   413  .  +  .
# 125372  scaffold_712  funannotate            gene   172   387  .  -  .
# 125373  scaffold_712  funannotate            mRNA   172   387  .  -  .
# 125374  scaffold_712  funannotate            exon   172   387  .  -  .
# 125375  scaffold_712  funannotate             CDS   172   387  .  -  0
#
#               Name                        Details
# 0             None                           None
# 1       MTE_000001  product=hypothetical_protein;
# 2       MTE_000001                           None
# 3       MTE_000001                           None
# 4       MTE_000001                           None
# ...            ...                            ...
# 125371  MTE_010713                           None
# 125372        None                           None
# 125373  MTE_010714  product=hypothetical_protein;
# 125374  MTE_010714                           None
# 125375  MTE_010714                           None
#
# [125376 rows x 10 columns]

# %%
#Take name from gene line and add it to mRNA line for each FUN
namedf = df.loc[df['Type'] == 'mRNA']
extradf = df.loc[df['Type'] == 'gene']

# %%
extradf
# Out:
#             Scaffold       Source  Type  Start    End  A  B  C  Name Details
# 0         scaffold_1  funannotate  gene     38   6230  .  -  .  None    None
# 22        scaffold_1  funannotate  gene  10546  12704  .  +  .  None    None
# 27        scaffold_1  funannotate  gene  14568  15728  .  +  .  None    None
# 33        scaffold_1  funannotate  gene  16317  20896  .  +  .  None    None
# 55        scaffold_1  funannotate  gene  21517  21865  .  +  .  None    None
# ...              ...          ...   ...    ...    ... .. .. ..   ...     ...
# 125355  scaffold_580  funannotate  gene     24    697  .  +  .  None    None
# 125359  scaffold_621  funannotate  gene     83    567  .  -  .  None    None
# 125363  scaffold_633  funannotate  gene      1    630  .  +  .  None    None
# 125369  scaffold_679  funannotate  gene    338    413  .  +  .  None    None
# 125372  scaffold_712  funannotate  gene    172    387  .  -  .  None    None
#
# [10785 rows x 10 columns]

# %%
finaldf = pd.merge(df.loc[df['Type'] == 'mRNA'],tpmdf,on='Name',how='left')

# %%
finaldf.to_csv('Mattiorlomyces_terfezioides_FULL.csv')

# %%
finaldf
# Out:
#            Scaffold       Source  Type  Start    End    A    B    C  \
# 0        scaffold_1  funannotate  mRNA    915   5180    .    -    .
# 1        scaffold_1  funannotate  mRNA  10546  12147    .    +    .
# 2        scaffold_1  funannotate  mRNA  14568  15728    .    +    .
# 3        scaffold_1  funannotate  mRNA  16317  20896    .    +    .
# 4        scaffold_1  funannotate  mRNA  21517  21865    .    +    .
# ...             ...          ...   ...    ...    ...  ...  ...  ...
# 10660  scaffold_580  funannotate  mRNA     24    697    .    +    .
# 10661  scaffold_621  funannotate  mRNA     83    567    .    -    .
# 10662  scaffold_633  funannotate  mRNA     19    468    .    +    .
# 10663           NaN          NaN   NaN    NaN    NaN  NaN  NaN  NaN
# 10664  scaffold_712  funannotate  mRNA    172    387    .    -    .
#
#              Name                                                  D     E  \
# 0      FUN_000001  Ontology_term=GO:0000956,GO:0008409,GO:0003676...  None
# 1      FUN_000002  Ontology_term=GO:0016491;Dbxref=InterPro:IPR00...  None
# 2      FUN_000003                           note=EggNog:ENOG503P4XH;  None
# 3      FUN_000004  Ontology_term=GO:0005524,GO:0003723,GO:0003724...  None
# 4      FUN_000005  Dbxref=InterPro:IPR039961;note=EggNog:ENOG503P...  None
# ...           ...                                                ...   ...
# 10660  FUN_010690                                               None  None
# 10661  FUN_010691                     note=COG:S,EggNog:ENOG503PHTC;  None
# 10662  FUN_010692  Dbxref=InterPro:IPR011993,InterPro:IPR001849,P...  None
# 10663  FUN_010693                                                NaN   NaN
# 10664  FUN_010694                     note=COG:A,EggNog:ENOG503BAHX;  None
#
#           F     G     H  mte-1-1_quants.sf  mte-1-2_quants.sf  \
# 0      None  None  None          49.918815          48.651117
# 1      None  None  None          29.904507          93.198164
# 2      None  None  None          50.562275          47.350504
# 3      None  None  None          19.525517          23.526021
# 4      None  None  None         160.174081         192.480128
# ...     ...   ...   ...                ...                ...
# 10660  None  None  None           1.712326           0.463956
# 10661  None  None  None           0.522796           0.000000
# 10662  None  None  None          50.116782          16.360833
# 10663   NaN   NaN   NaN           0.000000           0.000000
# 10664  None  None  None           0.000000           0.000000
#
#        mte-1-3_quants.sf  mte-2-1_quants.sf  mte-2-2_quants.sf  \
# 0              51.230655         114.005619         110.500698
# 1             110.905019          27.209175          24.818120
# 2              48.940137         102.872979         109.697093
# 3              25.051651          53.818736          49.702738
# 4             187.926480         212.566097         229.269026
# ...                  ...                ...                ...
# 10660           0.444573           0.000000           0.000000
# 10661           0.248775           1.584798           1.484800
# 10662          17.727651         350.414411         365.937848
# 10663           0.000000           0.000000           0.000000
# 10664           0.000000           0.000000           0.000000
#
#        mte-2-3_quants.sf
# 0             148.934214
# 1              19.239628
# 2              93.527605
# 3              38.678011
# 4             178.248348
# ...                  ...
# 10660           0.000000
# 10661           2.265384
# 10662         275.970411
# 10663           0.000000
# 10664           0.000000
#
# [10665 rows x 20 columns]
